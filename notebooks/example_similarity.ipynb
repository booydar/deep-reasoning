# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import os
import numpy as np
import datasets

# %%
model_name = "HuggingFaceTB/SmolLM2-135M"
model = AutoModelForCausalLM.from_pretrained(model_name, attn_implementation='eager')

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# text = 'I love cats'
texts =

# %%
inputs = tokenizer.batch_encode_plus([text], return_tensors='pt')

# %%
out = model(**inputs, output_attentions=True)

# %%
# Out:
# {'input_ids': tensor([[  57, 2606, 7680]]), 'attention_mask': tensor([[1, 1, 1]])}

# %%
out.keys()
# Out:
# odict_keys(['logits', 'past_key_values', 'attentions'])

# %%
attentions = out.attentions

# %%
len(model.model.layers)
# Out:
# 30

# %%
len(attentions)
# Out:
# 30

# %%
attentions[0].shape # b * n_heads * input_size * input_size
# Out:
# torch.Size([1, 9, 3, 3])

# %%
head_id_1 = 1
head_id_2 = 8

# %%
num_samples = 100
final_similarity = np.mean([0.5, 0.9, 0.95, ..., 0.99]) # average by samples

# %%
n_layers * (n_heads * n_heads)

# %%
# Out:
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.2747, 0.7253, 0.0000],
#         [0.0871, 0.2810, 0.6319]], grad_fn=<SelectBackward0>)

# %%
res_1 = attentions[0][0][head_id_1]
res_2 = attentions[0][0][head_id_2]

# %%
n_layers

# %%
mean()

# %%
def sim(head_id_1, head_id_2):

# %%
for id1 in range(9):
    for id2 in range(9):
        res.append(sim(id1, id2))

# %%
sim(0, 3a
    )

# %%
res_1 - res_2
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000],
#         [-0.1132,  0.1132,  0.0000],
#         [-0.4013, -0.1817,  0.5830]], grad_fn=<SubBackward0>)
